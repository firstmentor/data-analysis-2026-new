# %%
import matplotlib.pyplot as plt

students = ["Ram","Shyam","Mohan"]
marks = [80,90,70]

plt.bar(students, marks)
plt.show()

# %%
# Problem "Ab maan lo har student ke 2 subjects hain:
# students = ["Ram","Shyam","Mohan"]

# maths = [80,90,70]
# science = [75,85,65
#           | Student | Maths | Science |
# | ------- | ----- | ------- |
# | Ram     | 80    | 75      |
# | Shyam   | 90    | 85      |
# | Mohan   | 70    | 65      |
# Ab har student ke liye 2 bars chahiye.

# %%
# Position Banana
# Computer ko kaise pata chalega Ram, Shyam aur Mohan kahan rakhe?

# %%
import numpy as np

x = np.arange(len(students))

len(students)
x
# Out:
# array([0, 1, 2])

# %%
# Ram    = 0
# Shyam  = 1
# Mohan  = 2

# %%
# : Maths Bar
# plt.bar(x, maths)
# Position 0 -> Maths 80
# Position 1 -> Maths 90
# Position 2 -> Maths 70
#0        1        2
# █80      █90      █70

# %%
# Science Bar

# %%
# plt.bar(x, science)
# To Science bhi wahi position use karega:
# 0        1        2
# █80      █90      █70
# █75      █85      █65
# Bars overlap ho jayengi.

# %%
# Solution = Shift
# Maths ko thoda left bhejo:
# x - 0.2
# Science ko thoda right bhejo:
# x + 0.2
# Maths Position
# x = [0,1,2]

# x - 0.2
# [-0.2,0.8,1.8] Output:

# Science Position
# x + 0.2
[0.2,1.2,2.2] #output
# Out:
# [0.2, 1.2, 2.2]

# %%
# plt.xticks(x, students) kya karta hai?
# Abhi x-axis par numbers hain:
# 0   1   2
# plt.xticks(x, students)
# unhe replace karti hai:
# Ram   Shyam   Mohan

# %%
x = [0,1,2] → categories ki positions
x-0.2 → left shift
x+0.2 → right shift
width=0.4 → bar ki width
plt.xticks() → numbers ko names me badalta hai
plt.legend() → Maths aur Science ka label dikhata hai
