# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.4

# %%
#create array

# %%
list1 =[1,2,3]   #list
print(list1)
# Out:
# [1, 2, 3]

# %%
arr_list1 =np.array(list1)
print(arr_list1)  #array one d
# Out:
# [1 2 3]

# %%
print(type(arr_list1))  #n-dimensional array (multi-dimensional array)
# Out:
# <class 'numpy.ndarray'>

# %%
list1 =[1,2,3]
list2 =[4,5,6]
a =np.array([list1,list2])
print(a)  #2d array axio
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# # axis 0 → Rows (ऊपर से नीचे)
# # axis 1 → Columns (बाएँ से दाएँ)
# 2 Rows
# 3 Columns
# arr[0][0] = 1
# arr[1][2] = 6
# पहला index = Row
# दूसरा index = Column

# %%
list1 =[1,2,3]
list2 =[4,5,6]
list3 =[7,8,9]
arr_list1_3 =np.array([[list1,list2,list3]])
print(arr_list1_3)  #2d array axio
# Out:
# [[[1 2 3]
#   [4 5 6]
#   [7 8 9]]]

# %%
 print(arr_list1_3.ndim)
