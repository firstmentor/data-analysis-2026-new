# %%
#2 Basic Dataframe Understanding

# %%
# import pandas
import pandas as pd

# %%
data = {
    'Name': ['ram', 'ravi', 'ak', 'vj',"av","rj"],
    'Age': [26,37,28,19,4,3],
    'Salary': [10000, 3000, 40000, 50000,555,777]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  Salary
# 0   ram   26   10000
# 1  ravi   37    3000
# 2    ak   28   40000
# 3    vj   19   50000
# 4    av    4     555
# 5    rj    3     777

# %%
df.head(2) # top rows
# Out:
#    Name  Age  Salary
# 0   ram   26   10000
# 1  ravi   37    3000

# %%
df.tail(2) # last rows
# Out:
#   Name  Age  Salary
# 4   av    4     555
# 5   rj    3     777

# %%
df.shape # returns a tuple containing the shape of the DataFrame - rows & columns
# Out:
# (6, 3)

# %%
df.columns # list of column names in a dataframe
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns={'Salary': 'Monthly_Salary1'}) # rename abhi dataframe mai change nai hua hai
# Out:
#    Name  Age  Monthly_Salary1
# 0   ram   26            10000
# 1  ravi   37             3000
# 2    ak   28            40000
# 3    vj   19            50000
# 4    av    4              555
# 5    rj    3              777

# %%
df #abhi dataframe mai change nai hua hai
# Out:
#    Name  Age  Salary
# 0   ram   26   10000
# 1  ravi   37    3000
# 2    ak   28   40000
# 3    vj   19   50000
# 4    av    4     555
# 5    rj    3     777

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True) # rename column name/s

# %%
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
df.info()  # info method prints information about the DataFrame
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            6 non-null      str
#  1   Age             6 non-null      int64
#  2   Monthly_Salary  6 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 276.0 bytes

# %%
df.describe() # describe method generates descriptive statistics of DataFrame,
#only for numerical-value columns
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   27.500000    25750.000000
# std     7.416198    22779.742463
# min    19.000000     3000.000000
# 25%    24.250000     8250.000000
# 50%    27.000000    25000.000000
# 75%    30.250000    42500.000000
# max    37.000000    50000.000000

# %%
# save and load data from csv

# %%
df.to_csv('pn_data.csv')

# %%
df.to_csv('pn_data.csv', index=False) # save file - export data frame
