# %%
# import pandas
import pandas as pd

# %%
df= pd.read_csv('pn_data.csv') # load file - import dataframe
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
# 4 Rows & Columns - Selection

# %%
# select single column
df[['Name']]
# Out:
#    Name
# 0   ram
# 1  ravi
# 2    ak
# 3    vj
# 4    av
# 5    rj

# %%
# select multiple columns
df[['Name', 'Monthly_Salary']]
# Out:
#    Name  Monthly_Salary
# 0   ram           10000
# 1  ravi            3000
# 2    ak           40000
# 3    vj           50000
# 4    av             555
# 5    rj             777

# %%
# select single row || loc - label based index  // loc rows ko filter/select karta hai.
df.loc[df.Name=='ravi']
# Out:
#    Name  Age  Monthly_Salary
# 1  ravi   37            3000

# %%
# select multiple rows || loc - label based index
df.loc[(df.Name=='ram') & (df.Monthly_Salary>=9000)]
# Out:
#   Name  Age  Monthly_Salary
# 0  ram   26           10000

# %%
df.loc[0:2]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000

# %%
# Select Rows || iloc - index-value based
# df.iloc[0]
df.iloc[0:2] # [start:stop:step]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000

# %%
df.loc[0:2]  #0 2 include index
df.iloc[0:2]  #[start:stop:step]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000

# %%
# 5 Filter Dataframe - Filtering by column values

# %%
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
df['Age'] >18
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# Name: Age, dtype: bool

# %%
df[df['Age']>=18]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000

# %%
df_age_filter = df[df['Age'] >= 18] # filter and store dataframe in a new variable

# %%
df_age_filter
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000

# %%
df[(df['Age'] >= 28) & (df['Monthly_Salary'] >= 3000)] # multiple filter conditions
# Out:
#    Name  Age  Monthly_Salary
# 1  ravi   37            3000
# 2    ak   28           40000

# %%
df.where(df['Age'] >= 28) # where function replace values in a DataFrame based on a condition
# df[df['Age']>=28]

# Method	क्या करता है
# where()	condition false होने पर NaN डालता है
# loc[]	false rows को हटा देता है

# where() data cleaning और masking में बहुत use होता है।
# Out:
#    Name   Age  Monthly_Salary
# 0   NaN   NaN             NaN
# 1  ravi  37.0          3000.0
# 2    ak  28.0         40000.0
# 3   NaN   NaN             NaN
# 4   NaN   NaN             NaN
# 5   NaN   NaN             NaN

# %%
df.where(df['Age'] >= 28, other = 'Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1          ravi            37           3000
# 2            ak            28          40000
# 3  Not Eligible  Not Eligible   Not Eligible
# 4  Not Eligible  Not Eligible   Not Eligible
# 5  Not Eligible  Not Eligible   Not Eligible

# %%
# 6 Rows and Columns - Operation (Add, update, delete)

# %%
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
df.drop('DOJ2', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop('DOJ2', axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...

# %%
df

# %%
# Create a new column
df['college'] = ['rjit', 'itm', 'mpct', 'mits','abc','vck']
df
# Out:
#    Name  Age  Monthly_Salary college
# 0   ram   26           10000    rjit
# 1  ravi   37            3000     itm
# 2    ak   28           40000    mpct
# 3    vj   19           50000    mits
# 4    av    4             555     abc
# 5    rj    3             777     vck

# %%
# Add new columns using existing column/s
df['Bonus'] = df['Salary'] * 0.20
df
# Out:
#    Name  Age  Salary college    Bonus
# 0   ram   26   90000    rjit  18000.0
# 1  ravi   37    3000     itm    600.0
# 2    ak   28   40000    mpct   8000.0
# 3    vj   19   50000    mits  10000.0
# 4    av    4     555     abc    111.0
# 5    rj    3     777     vck    155.4

# %%
# Add new row - at the end of dataframe
df.loc[len(df)] = ['viki', 23, 2000, 'mpct', 1000]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Add new row - at the end of dataframe
# ----> 2 df.loc[len(df)] = ['viki', 23, 2000, 'mpct', 1000]
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1943, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1940     indexer, missing = convert_missing_indexer(indexer)
#    1942     if missing:
# ...

# %%
# update value in dataframe using index-name
df.loc[0, 'Salary'] = 5000
df
# Out:
#    Name  Age  Salary college    Bonus
# 0   ram   26    5000    rjit  18000.0
# 1  ravi   37    3000     itm    600.0
# 2    ak   28   40000    mpct   8000.0
# 3    vj   19   50000    mits  10000.0
# 4    av    4     555     abc    111.0
# 5    rj    3     777     vck    155.4
# 6  viki   23    2000    mpct   1000.0

# %%
# update value in dataframe using column-value
df.loc[df.Name=='ram','Salary'] = 110000
df
# Out:
#    Name  Age  Salary college    Bonus
# 0   ram   26  110000    rjit  18000.0
# 1  ravi   37    3000     itm    600.0
# 2    ak   28   40000    mpct   8000.0
# 3    vj   19   50000    mits  10000.0
# 4    av    4     555     abc    111.0
# 5    rj    3     777     vck    155.4
# 6  viki   23    2000    mpct   1000.0

# %%
# delete value - rows and columns

# %%
# delete row using column-value filter
df = df.drop(df[df.Name == 'viki'].index) # delete row, axis= 0

# %%
df
# Out:
#    Name  Age  Salary college    Bonus
# 0   ram   26  110000    rjit  18000.0
# 1  ravi   37    3000     itm    600.0
# 2    ak   28   40000    mpct   8000.0
# 3    vj   19   50000    mits  10000.0
# 4    av    4     555     abc    111.0
# 5    rj    3     777     vck    155.4

# %%
# delete row using index-name filter
df.drop(1, axis=0)
# Out:
#   Name  Age  Salary college    Bonus
# 0  ram   26  110000    rjit  18000.0
# 2   ak   28   40000    mpct   8000.0
# 3   vj   19   50000    mits  10000.0
# 4   av    4     555     abc    111.0
# 5   rj    3     777     vck    155.4

# %%
df.drop('Bonus', axis=1, inplace=True) # delete one column
# df.drop(['Bonus', 'Team'], axis=1, inplace=True) # delete multiple columns

# %%
df
# Out:
#    Name  Age  Salary college
# 0   ram   26  110000    rjit
# 1  ravi   37    3000     itm
# 2    ak   28   40000    mpct
# 3    vj   19   50000    mits
# 4    av    4     555     abc
# 5    rj    3     777     vck

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True) # rename column name

# %%
df
# Out:
#    Name  Age  Monthly_Salary college
# 0   ram   26          110000    rjit
# 1  ravi   37            3000     itm
# 2    ak   28           40000    mpct
# 3    vj   19           50000    mits
# 4    av    4             555     abc
# 5    rj    3             777     vck

# %%
# sort values - order values in dataframe by asc or desc order
df.sort_values('Monthly_Salary') #ascending order, by default
# Out:
#    Name  Age  Monthly_Salary college
# 4    av    4             555     abc
# 5    rj    3             777     vck
# 1  ravi   37            3000     itm
# 2    ak   28           40000    mpct
# 3    vj   19           50000    mits
# 0   ram   26          110000    rjit

# %%
# sort values in descending order
df.sort_values('Monthly_Salary', ascending=False)
# Out:
#    Name  Age  Monthly_Salary college
# 0   ram   26          110000    rjit
# 3    vj   19           50000    mits
# 2    ak   28           40000    mpct
# 1  ravi   37            3000     itm
# 5    rj    3             777     vck
# 4    av    4             555     abc

# %%
# 7 working with date value

# %%
# create a date column - date of joining
df['DOJ2'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03','2024-04-03','2024-05-01']
df
# Out:
#    Name  Age  Monthly_Salary college        DOJ2
# 0   ram   26           10000    rjit  2024-01-01
# 1  ravi   37            3000     itm  2024-01-15
# 2    ak   28           40000    mpct  2024-03-28
# 3    vj   19           50000    mits  2024-03-03
# 4    av    4             555     abc  2024-04-03
# 5    rj    3             777     vck  2024-05-01

# %%
df.drop('DOJ23', axis=1, inplace=True) # delete one column

# %%
df
# Out:
#    Name  Age  Salary college        DOJ2
# 0   ram   26   90000    rjit  2024-01-01
# 1  ravi   37    3000     itm  2024-01-15
# 2    ak   28   40000    mpct  2024-03-28
# 3    vj   19   50000    mits  2024-03-03
# 4    av    4     555     abc  2024-04-03
# 5    rj    3     777     vck  2024-05-01

# %%
df['DOJ2'].dtype # object-type value
# dtype('O')
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ2'] = pd.to_datetime(df['DOJ2']) # change to date-time type

# %%
df['DOJ2'].dtype # date-time type
# Out:
# dtype('<M8[us]')

# %%
df1 = df

# %%
# creating a new column with incorrect date format
df1['DOJ23'] = ['01-01-2025', '15-01-2025', '28-03-2025', '03-03-2025','03-03-2025','03-03-2025']
df1
# Out:
#    Name  Age  Monthly_Salary college       DOJ2       DOJ23
# 0   ram   26           10000    rjit 2024-01-01  01-01-2025
# 1  ravi   37            3000     itm 2024-01-15  15-01-2025
# 2    ak   28           40000    mpct 2024-03-28  28-03-2025
# 3    vj   19           50000    mits 2024-03-03  03-03-2025
# 4    av    4             555     abc 2024-04-03  03-03-2025
# 5    rj    3             777     vck 2024-05-01  03-03-2025

# %%
df1['DOJ23'].dtype  # object-type value
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df1['DOJ23'] = pd.to_datetime(df1['DOJ23'], format = '%d-%m-%Y') # change to date-time type using date-format

# %%
df1['DOJ23'].dtype
# Out:
# dtype('<M8[us]')

# %%
df1
# Out:
#    Name  Age  Monthly_Salary college       DOJ2      DOJ23
# 0   ram   26           10000    rjit 2024-01-01 2025-01-01
# 1  ravi   37            3000     itm 2024-01-15 2025-01-15
# 2    ak   28           40000    mpct 2024-03-28 2025-03-28
# 3    vj   19           50000    mits 2024-03-03 2025-03-03
# 4    av    4             555     abc 2024-04-03 2025-03-03
# 5    rj    3             777     vck 2024-05-01 2025-03-03

# %%
# extract year, month, week, day
df['DOJ2'].dt.year
# df['DOJ2'].dt.month
# df['DOJ2'].dt.day
# df['DOJ2'].dt.day_name()
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# 5    2024
# Name: DOJ2, dtype: int32

# %%
# create new column using month extract function from DOJ2 column
df['Month'] = df['DOJ2'].dt.month

# %%
df
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26           10000    rjit 2024-01-01      1
# 1  ravi   37            3000     itm 2024-01-15      1
# 2    ak   28           40000    mpct 2024-03-28      3
# 3    vj   19           50000    mits 2024-03-03      3
# 4    av    4             555     abc 2024-04-03      4
# 5    rj    3             777     vck 2024-05-01      5

# %%
df['DOJ2'] + pd.Timedelta(days=90) # add 90 days to DOJ column
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# 4   2024-07-02
# 5   2024-07-30
# Name: DOJ2, dtype: datetime64[us]

# %%
# 8 Handling Missing Values

# %%
df
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26           10000    rjit 2024-01-01      1
# 1  ravi   37            3000     itm 2024-01-15      1
# 2    ak   28           40000    mpct 2024-03-28      3
# 3    vj   19           50000    mits 2024-03-03      3
# 4    av    4             555     abc 2024-04-03      4
# 5    rj    3             777     vck 2024-05-01      5

# %%
df.isnull() #  Detect missing values
# Out:
#     Name    Age  Monthly_Salary  college   DOJ2  Month
# 0  False  False           False    False  False  False
# 1  False  False           False    False  False  False
# 2  False  False           False    False  False  False
# 3  False  False           False    False  False  False
# 4  False  False           False    False  False  False
# 5  False  False           False    False  False  False

# %%
import numpy as np  # to create null values below

# %%
df.loc[df.Name=='ram', 'Monthly_Salary'] = np.nan # adding a null value

# %%
df
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26         10000.0    rjit 2024-01-01      1
# 1  ravi   37          3000.0     itm 2024-01-15      1
# 2    ak   28         40000.0    mpct 2024-03-28      3
# 3    vj   19         50000.0    mits 2024-03-03      3
# 4    av    4           555.0     abc 2024-04-03      4
# 5    rj    3             NaN     vck 2024-05-01      5

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary  college   DOJ2  Month
# 0  False  False           False    False  False  False
# 1  False  False           False    False  False  False
# 2  False  False           False    False  False  False
# 3  False  False           False    False  False  False
# 4  False  False           False    False  False  False
# 5  False  False            True    False  False  False

# %%
df.loc[df.Name=='ram', 'college'] = np.nan # adding a null value

# %%
df
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26         10000.0     NaN 2024-01-01      1
# 1  ravi   37          3000.0     itm 2024-01-15      1
# 2    ak   28         40000.0    mpct 2024-03-28      3
# 3    vj   19         50000.0    mits 2024-03-03      3
# 4    av    4           555.0     abc 2024-04-03      4
# 5    rj    3             NaN     vck 2024-05-01      5

# %%
df.isnull().sum() # count of null values by columns
# Out:
# Name              0
# Age               0
# Monthly_Salary    1
# college           1
# DOJ2              0
# Month             0
# dtype: int64

# %%
df.fillna(0) # fill null values with 0
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26         10000.0       0 2024-01-01      1
# 1  ravi   37          3000.0     itm 2024-01-15      1
# 2    ak   28         40000.0    mpct 2024-03-28      3
# 3    vj   19         50000.0    mits 2024-03-03      3
# 4    av    4           555.0     abc 2024-04-03      4
# 5    rj    3             0.0     vck 2024-05-01      5

# %%
df.loc[df.Name=='ram', 'Monthly_Salary'] = 30000
df.loc[df.Name.isin(['ram', 'rj']), 'Monthly_Salary'] = 20000

# %%
df
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26         20000.0     NaN 2024-01-01      1
# 1  ravi   37          3000.0     itm 2024-01-15      1
# 2    ak   28         40000.0    mpct 2024-03-28      3
# 3    vj   19         50000.0    mits 2024-03-03      3
# 4    av    4           555.0     abc 2024-04-03      4
# 5    rj    3         20000.0     vck 2024-05-01      5

# %%
df.fillna(0) # fill null values with 0
# Out:
#    Name  Age  Monthly_Salary college       DOJ2  Month
# 0   ram   26         20000.0       0 2024-01-01      1
# 1  ravi   37          3000.0     itm 2024-01-15      1
# 2    ak   28         40000.0    mpct 2024-03-28      3
# 3    vj   19         50000.0    mits 2024-03-03      3
# 4    av    4           555.0     abc 2024-04-03      4
# 5    rj    3         20000.0     vck 2024-05-01      5

# %%
df
# Out:
#    Name  Age   Salary college       DOJ2  Month
# 0   ram   26  30000.0    rjit 2024-01-01      1
# 1  ravi   37   3000.0     itm 2024-01-15      1
# 2    ak   28  40000.0    mpct 2024-03-28      3
# 3    vj   19  50000.0    mits 2024-03-03      3
# 4    av    4    555.0     abc 2024-04-03      4
# 5    rj    3      NaN     vck 2024-05-01      5
