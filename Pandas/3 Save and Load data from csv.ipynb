# %%
# import pandas
import pandas as pd

# %%
df= pd.read_csv('pn_data.csv') # load file - import dataframe
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
# 4 Rows & Columns - Selection

# %%
# select single column
df[['Name']]
# Out:
#    Name
# 0   ram
# 1  ravi
# 2    ak
# 3    vj
# 4    av
# 5    rj

# %%
# select multiple columns
df[['Name', 'Monthly_Salary']]
# Out:
#    Name  Monthly_Salary
# 0   ram           10000
# 1  ravi            3000
# 2    ak           40000
# 3    vj           50000
# 4    av             555
# 5    rj             777

# %%
# select single row || loc - label based index  // loc rows ko filter/select karta hai.
df.loc[df.Name=='ravi']
# Out:
#    Name  Age  Monthly_Salary
# 1  ravi   37            3000

# %%
# select multiple rows || loc - label based index
df.loc[(df.Name=='ram') & (df.Monthly_Salary>=9000)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Monthly_Salary]
# Index: []

# %%
df.loc[0:2]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000

# %%
# Select Rows || iloc - index-value based
# df.iloc[0]
df.iloc[0:2] # [start:stop:step]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000

# %%
df.loc[0:2]  #0 2 include index
df.iloc[0:2]  #[start:stop:step]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000

# %%
# 5 Filter Dataframe - Filtering by column values

# %%
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000
# 4    av    4             555
# 5    rj    3             777

# %%
df['Age'] >18
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# Name: Age, dtype: bool

# %%
df[df['Age']>=18]
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000

# %%
df_age_filter = df[df['Age'] >= 18] # filter and store dataframe in a new variable

# %%
df_age_filter
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000

# %%
df[(df['Age'] >= 28) & (df['Monthly_Salary'] >= 3000)] # multiple filter conditions
# Out:
#    Name  Age  Monthly_Salary
# 1  ravi   37            3000
# 2    ak   28           40000

# %%
df.where(df['Age'] >= 28) # where function replace values in a DataFrame based on a condition
# df[df['Age']>=28]

# Method	क्या करता है
# where()	condition false होने पर NaN डालता है
# loc[]	false rows को हटा देता है

# where() data cleaning और masking में बहुत use होता है।
# Out:
#    Name   Age  Monthly_Salary
# 0   NaN   NaN             NaN
# 1  ravi  37.0          3000.0
# 2    ak  28.0         40000.0
# 3   NaN   NaN             NaN
# 4   NaN   NaN             NaN
# 5   NaN   NaN             NaN

# %%
df.where(df['Age'] >= 28, other = 'Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1          ravi            37           3000
# 2            ak            28          40000
# 3  Not Eligible  Not Eligible   Not Eligible

# %%
# 6 Rows and Columns - Operation (Add, update, delete)

# %%
df
# Out:
#    Name  Age  Monthly_Salary
# 0   ram   26           10000
# 1  ravi   37            3000
# 2    ak   28           40000
# 3    vj   19           50000

# %%
# Create a new column
df['college'] = ['rjit', 'itm', 'mpct', 'mits']
df
# Out:
#    Name  Age  Monthly_Salary college
# 0   ram   26           10000    rjit
# 1  ravi   37            3000     itm
# 2    ak   28           40000    mpct
# 3    vj   19           50000    mits

# %%
# Add new columns using existing column/s
df['Bonus'] = df['Monthly_Salary'] * 0.20
df
# Out:
#    Name  Age  Monthly_Salary college    Bonus
# 0   ram   26           10000    rjit   2000.0
# 1  ravi   37            3000     itm    600.0
# 2    ak   28           40000    mpct   8000.0
# 3    vj   19           50000    mits  10000.0

# %%
# Add new row - at the end of dataframe
df.loc[len(df)] = ['viki', 23, 2000, 'mpct', 1000]
df
# Out:
#    Name  Age  Monthly_Salary college    Bonus
# 0   ram   26           10000    rjit   2000.0
# 1  ravi   37            3000     itm    600.0
# 2    ak   28           40000    mpct   8000.0
# 3    vj   19           50000    mits  10000.0
# 4  viki   23            2000    mpct   1000.0

# %%
# update value in dataframe using index-name
df.loc[0, 'Monthly_Salary'] = 5000
df
# Out:
#    Name  Age  Monthly_Salary college    Bonus
# 0   ram   26            5000    rjit   2000.0
# 1  ravi   37            3000     itm    600.0
# 2    ak   28           40000    mpct   8000.0
# 3    vj   19           50000    mits  10000.0
# 4  viki   23            2000    mpct   1000.0

# %%
# update value in dataframe using column-value
df.loc[df.Name=='ram','Monthly_Salary'] = 90000
df
# Out:
#    Name  Age  Monthly_Salary college    Bonus
# 0   ram   26           90000    rjit   2000.0
# 1  ravi   37            3000     itm    600.0
# 2    ak   28           40000    mpct   8000.0
# 3    vj   19           50000    mits  10000.0
# 4  viki   23            2000    mpct   1000.0

# %%
# delete value - rows and columns

# %%
# delete row using column-value filter
df = df.drop(df[df.Name == 'viki'].index) # delete row, axis= 0

# %%
# delete row using index-name filter
df.drop(1, axis=0)
# Out:
#   Name  Age  Monthly_Salary college    Bonus
# 0  ram   26           90000    rjit   2000.0
# 2   ak   28           40000    mpct   8000.0
# 3   vj   19           50000    mits  10000.0

# %%
df.drop('Bonus', axis=1, inplace=True) # delete one column
# df.drop(['Bonus', 'Team'], axis=1, inplace=True) # delete multiple columns

# %%
df
# Out:
#    Name  Age  Monthly_Salary college
# 0   ram   26           90000    rjit
# 1  ravi   37            3000     itm
# 2    ak   28           40000    mpct
# 3    vj   19           50000    mits

# %%
df.rename(columns={'Monthly_Salary': 'Salary'}, inplace=True) # rename column name

# %%
df
# Out:
#    Name  Age  Salary college
# 0   ram   26   90000    rjit
# 1  ravi   37    3000     itm
# 2    ak   28   40000    mpct
# 3    vj   19   50000    mits

# %%
# sort values - order values in dataframe by asc or desc order
df.sort_values('Salary') #ascending order, by default
# Out:
#    Name  Age  Salary college
# 1  ravi   37    3000     itm
# 2    ak   28   40000    mpct
# 3    vj   19   50000    mits
# 0   ram   26   90000    rjit

# %%
# sort values in descending order
df.sort_values('Salary', ascending=False)
# Out:
#    Name  Age  Salary college
# 0   ram   26   90000    rjit
# 3    vj   19   50000    mits
# 2    ak   28   40000    mpct
# 1  ravi   37    3000     itm

# %%
# 7 working with date value

# %%
# create a date column - date of joining
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']
df
# Out:
#    Name  Age  Salary college         DOJ
# 0   ram   26   90000    rjit  2024-01-01
# 1  ravi   37    3000     itm  2024-01-15
# 2    ak   28   40000    mpct  2024-03-28
# 3    vj   19   50000    mits  2024-03-03

# %%
df['DOJ'].dtype # object-type value
# dtype('O')
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ']) # change to date-time type

# %%
df['DOJ'].dtype # date-time type
# Out:
# dtype('<M8[us]')

# %%
df1 = df

# %%
# creating a new column with incorrect date format
df1['DOJ2'] = ['01-01-2025', '15-01-2025', '28-03-2025', '03-03-2025']
df1
# Out:
#    Name  Age  Salary college        DOJ        DOJ2
# 0   ram   26   90000    rjit 2024-01-01  01-01-2025
# 1  ravi   37    3000     itm 2024-01-15  15-01-2025
# 2    ak   28   40000    mpct 2024-03-28  28-03-2025
# 3    vj   19   50000    mits 2024-03-03  03-03-2025

# %%
df1['DOJ2'].dtype  # object-type value
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df1['DOJ2'] = pd.to_datetime(df1['DOJ2'], format = '%d-%m-%Y') # change to date-time type using date-format

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[us]')

# %%
df = df.drop('DOJ2', axis=1)
df
# Out:
#    Name  Age  Salary college        DOJ
# 0   ram   26   90000    rjit 2024-01-01
# 1  ravi   37    3000     itm 2024-01-15
# 2    ak   28   40000    mpct 2024-03-28
# 3    vj   19   50000    mits 2024-03-03

# %%
# extract year, month, week, day
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Monday
# 1      Monday
# 2    Thursday
# 3      Sunday
# Name: DOJ, dtype: str

# %%
# create new column using month extract function from DOJ column
df['Month'] = df['DOJ'].dt.month

# %%
df
# Out:
#    Name  Age  Salary college        DOJ  Month
# 0   ram   26   90000    rjit 2024-01-01      1
# 1  ravi   37    3000     itm 2024-01-15      1
# 2    ak   28   40000    mpct 2024-03-28      3
# 3    vj   19   50000    mits 2024-03-03      3

# %%
df['DOJ'] + pd.Timedelta(days=90) # add 90 days to DOJ column
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# Name: DOJ, dtype: datetime64[us]

# %%
# 8 Handling Missing Values
